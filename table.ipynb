# %%
import pandas as pd

data = pd.read_csv('results/manual_scores.csv')

data
# Out:
#     experiment_name  temperature  top_k prompt_style prompt_label question_id  \
# 0             exp01          0.2      3       strict            A         q01
# 1             exp01          0.2      3       strict            A         q02
# 2             exp01          0.2      3       strict            A         q03
# 3             exp01          0.2      3       strict            A         q04
# 4             exp01          0.2      3       strict            A         q05
# ..              ...          ...    ...          ...          ...         ...
# 103           exp06          0.5      7        loose            C         q14
# 104           exp06          0.5      7        loose            C         q15
# 105           exp06          0.5      7        loose            C         q16
# 106           exp06          0.5      7        loose            C         q17
# 107           exp06          0.5      7        loose            C         q18
#
# ...
